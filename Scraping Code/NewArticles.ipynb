# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
import urllib.parse

# %%
client=MongoClient("mongodb+srv://scnamjoshi:"+urllib.parse.quote("Awsedr@12")+"@cluster0.2mur7.mongodb.net/sample_supplies.sales?retryWrites=true&w=majority")

# %%
db=client.get_database('sample_supplies')

# %%
rec=db.sales

# %%
rec.count_documents({})
# Out:
# 5000

# %%
list(rec.find())
# Out:
# [{'_id': ObjectId('5bd761dcae323e45a93ccfed'),
#   'saleDate': datetime.datetime(2015, 9, 2, 16, 11, 59, 565000),
#   'items': [{'name': 'binder',
#     'tags': ['school', 'general', 'organization'],
#     'price': Decimal128('13.44'),
#     'quantity': 8},
#    {'name': 'binder',
#     'tags': ['school', 'general', 'organization'],
#     'price': Decimal128('16.66'),
#     'quantity': 10}],
#   'storeLocation': 'London',
#   'customer': {'gender': 'M',
#    'age': 44,
#    'email': 'owtar@pu.cd',
#    'satisfaction': 2},
#   'couponUsed': False,
#   'purchaseMethod': 'In store'},
#  {'_id': ObjectId('5bd761dcae323e45a93ccff3'),
#   'saleDate': datetime.datetime(2015, 7, 22, 2, 45, 20, 727000),
#   'items': [{'name': 'envelopes',
#     'tags': ['stationary', 'office', 'general'],
#     'price': Decimal128('21.46'),
#     'quantity': 5},
#    {'name': 'notepad',
#     'tags': ['office', 'writing', 'school'],
#     'price': Decimal128('21.82'),
#     'quantity': 1},
# ...

# %%
pip install newspaper3k
# Out:
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13537 sha256=275c9e0f66140dc0d0c602e42ab0b58b2e39fb36bcdaa0681176f2c39c6b4a62
#   Stored in directory: c:\users\pande\appdata\local\pip\cache\wheels\99\74\83\8fac1c8d9c648cfabebbbffe97a889f6624817f3aa0bbe6c09
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3354 sha256=fa42c4400101c6b24132308778e197e4b16d2fd59376409788ea3f6c5a1e8b44
#   Stored in directory: c:\users\pande\appdata\local\pip\cache\wheels\b6\09\68\a9f15498ac02c23dde29f18745bc6a6f574ba4ab41861a3575
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398406 sha256=390477c5523a0c8d56f60053363944d7258d2c202045bcbde4255b81537fe148
#   Stored in directory: c:\users\pande\appdata\local\pip\cache\wheels\1f\7e\0c\54f3b0f5164278677899f2db08f2b07943ce2d024a3c862afb
# ...

# %%
pip install GoogleNews
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from GoogleNews import GoogleNews
from newspaper import Article
from newspaper import Config
from wordcloud import WordCloud, STOPWORDS

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from GoogleNews import GoogleNews
from newspaper import Article
from newspaper import Config
from wordcloud import WordCloud, STOPWORDS

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
now = dt.date.today()
now = now.strftime('%m-%d-%Y')
yesterday = dt.date.today() - dt.timedelta(days = 1)
yesterday = yesterday.strftime('%m-%d-%Y')

nltk.download('punkt')
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 10
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pande\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# save the company name in a variable
import time
company_name = input("Please provide the name of the Company or a Ticker: ")
#As long as the company name is valid, not empty...
if company_name != '':
    print(f'Searching for and analyzing {company_name}, Please be patient, it might take a while...')

    #Extract News with Google News
    #googlenews = GoogleNews(start=yesterday,end=now)
    
    googlenews = GoogleNews()
    #googlenews = GoogleNews(period='360d')
    
    googlenews.search(company_name)
    googlenews.set_time_range('01/11/2022','01/11/2022')
    result = googlenews.result()
    
    total_count=googlenews.total_count()
    print(total_count)
    #page_nos=int(total_count/10)
    #page_init=1
    df_Jan = pd.DataFrame()
    #while (page_init < 3):
     #   result=googlenews.page_at(page_init)
      #  page_init+=1
      #  time.sleep(3)
        #store the results
    df_Jan = df_Jan.append(result)

df_Jan
# Out:
# Please provide the name of the Company or a Ticker: Reliance Industries
# Searching for and analyzing Reliance Industries, Please be patient, it might take a while...
# 10500000
#                                                title                  media  \
# 0  Largecap stock picks: Reliance Industries, Tat...  The Financial Express
# 1  LIC IPO Likely To Make State-Owned Insurer Ind...               Swarajya
# 2  LIC IPO could make the PSU India's second larg...     The Economic Times
# 3  How Amazon's retail battle with Reliance turne...  Retail News from Asia
# 4  Sensex Rises Over 500 Points, Nifty Reclaims 1...          Outlook India
# 5  Sensex Rises Over 300 Points, Nifty Above 18,1...          Outlook India
# 6   Reliance Industries Trades Higher On The Bourses           Udaipur News
# 7  Nifty to hit 18150, Sensex may reach 61100 ami...  The Financial Express
# 8  The reason why Kishore Biyani can't take a che...     The Economic Times
# ...

# %%
df_Feb.reset_index(inplace=True)

# %%
df_June_1 = df_June.iloc[1: , :]

# %%
import datetime

# %%
df_Feb['DateNew']=df_Feb['datetime'].dt.date
df_Feb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-2b3fbf2fa627> in <module>
# ----> 1 df_Feb['DateNew']=df_Feb['datetime'].dt.date
#       2 df_Feb
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# E:\Anaconda\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df_Feb['date']
# Out:
# 0      8-Nov-2021
# 1      8-Feb-2021
# 2      8-Feb-2021
# 3      8-Feb-2021
# 4      8-Feb-2021
#           ...
# 145    9-Feb-2021
# 146    9-Feb-2021
# 147    9-Feb-2021
# 148    9-Feb-2021
# 149    9-Feb-2021
# Name: date, Length: 150, dtype: object

# %%
from datetime import datetime
end = datetime.now()
end=end.date()
print(end)
df_Jan['DateNew'] = df_Jan['DateNew'].fillna(end)
df_Jan
# Out:
# 2022-01-09
#     index                                              title  \
# 0       0  TCS pips Reliance Industries to become India's...
# 1       1  Amazon moves Delhi High Court; seeks arrest of...
# 2       2  Amazon asks Delhi HC to jail Future Group’s Ki...
# 3       3  Reliance Jio Planning To Bring IoT Services To...
# 4       4  Sensex, Nifty Fall For Third Day In A Row; Rel...
# 5       5  Reliance Industries shares fall nearly 5% as C...
# 6       6  RIL top Sensex loser today, plunges over 5.5% ...
# 7       7  TCS surpasses Reliance to become the most valu...
# 8       8  Reliance Industries (RIL) share price declines...
# 9       9  Reliance Retail acquired pharmacy, Netmeds' in...
# 10      0  RIL top Sensex loser today, plunges over 5.5% ...
# 11      1  Amazon tries to block Future's asset sale to R...
# 12      2  Reliance Retail acquired pharmacy, Netmeds' in...
# 13      3         RIL Spins Off O2C Business Into A New Unit
# ...

# %%
try:
    list =[] #creating an empty list 
    for i in df_Feb.index:
        dict = {} #creating an empty dictionary to append an article in every single iteration
        article = Article(df_Feb['link'][i],config=config) #providing the link
        try:
          article.download() #downloading the article 
          article.parse() #parsing the article
          article.nlp() #performing natural language processing (nlp)
        except:
           pass 
        #storing results in our empty dictionary
        dict['Date']=df_Feb['DateNew'][i]
        dict['Media']=df_Feb['media'][i]
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        dict['Key_words']=article.keywords
        list.append(dict)
    check_empty = not any(list)
    # print(check_empty)
    if check_empty == False:
        news_df_Feb=pd.DataFrame(list) #creating dataframe
        print(news_df_Feb)

except Exception as e:
    #exception handling
    print("exception occurred:" + str(e))
    print('Looks like, there is some error in retrieving the data, Please try again or try with a different ticker.' )
# Out:
#            Date                    Media  \
# 0    8-Nov-2021             Odisha Diary
# 1    8-Feb-2021          Bloomberg Quint
# 2    8-Feb-2021                     Mint
# 3    8-Feb-2021  The Hindu Business Line
# 4    8-Feb-2021           Business Today
# ..          ...                      ...
# 145  9-Feb-2021                Scroll.in
# 146  9-Feb-2021                    Inc42
# 147  9-Feb-2021                     Mint
# 148  9-Feb-2021                 The Wire
# 149  9-Feb-2021           Business Today
#
#                                                  Title  \
# 0    Reliance Eagleford Upstream Holding Lp Signs A...
# 1    Analysts’ Take On The New Reliance Jiophone 20...
# 2    Reliance buys majority stake in skyTran; Amban...
# 3    Reliance Ind arm ups stake in US-based skyTran...
# 4    Mukesh Ambani security scare: Jaish-ul-Hind cl...
# ..                                                 ...
# 145  Farmers’ protest: Reliance Jio lost over 20 la...
# ...

# %%
testFeb=news_df_Feb.groupby(['Date'], as_index = False).agg({'Summary': ','.join,'Article':','.join})

# %%
testFeb=testFeb.replace('8-Nov-2021','2021-11-08')
testFeb
# Out:
#           Date                                            Summary  \
# 0   2021-02-01  Meanwhile, Tata Consultancy Services (TCS) was...
# 1   2021-02-02  The verdict is a win for Amazon which says Fut...
# 2   2021-02-20  New Delhi: Last year it was revealed that Reli...
# 3   2021-02-03  ,Reliance had outstanding debt of $35.2 billio...
# 4   2021-02-04  The Ambanis, a billionaire family that owns th...
# 5   2021-02-05  The Mukesh Ambani-led Reliance Industries (RIL...
# 6   2021-02-06  A vehicle with explosives was found abandoned ...
# 7   2021-02-07  Reliance Industries chairperson Mukesh Ambani....
# 8   2021-02-08  Reliance Jio Infocomm Ltd.’s new Jiophone offe...
# 9   2021-11-08  MUMBAI: Reliance Eagleford Upstream Holding, L...
# 10  2021-02-09  Similarly, in Haryana, its subscriber base fel...
#
#                                               Article
# 0   The market capitalisation of eight out of 10 m...
# 1   The verdict is a win for Amazon which says Fut...
# ...

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole)

#Assigning Initial Values
positive = 0
negative = 0
neutral = 0
#Creating empty lists
#news_list = []
neutral_list = []
negative_list = []
positive_list = []

#Iterating over the tweets in the dataframe
for news in test123['Summary']:
    #news_list.append(news)
    analyzer = SentimentIntensityAnalyzer().polarity_scores(news)
    neg = analyzer['neg']
    neu = analyzer['neu']
    pos = analyzer['pos']
    comp = analyzer['compound']
    print(neg,pos,neu,comp)
# Out:
# 0.034 0.108 0.859 1.0
# 0.023 0.063 0.914 0.9971
# 0.014 0.093 0.893 0.9998
# 0.017 0.062 0.921 0.9961
# 0.004 0.062 0.935 0.9432
# 0.023 0.11 0.867 0.9965
# 0.018 0.111 0.87 0.9887
# 0.011 0.108 0.882 0.9996
# 0.009 0.08 0.911 0.9837
# 0.064 0.122 0.815 0.9912

# %%
    if neg > pos:
        negative_list.append(news) #appending the news that satisfies this condition
        negative += 1 #increasing the count by 1
    elif pos > neg:
        positive_list.append(news) #appending the news that satisfies this condition
        positive += 1 #increasing the count by 1
    elif pos == neg:
        neutral_list.append(news) #appending the news that satisfies this condition
        neutral += 1 #increasing the count by 1 

positive = percentage(positive, len(news_df)) #percentage is the function defined above
negative = percentage(negative, len(news_df))
neutral = percentage(neutral, len(news_df))

print(pos)
# Out:
# 0.195

# %%
#Converting lists to pandas dataframe
news_list = pd.DataFrame(news_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
#using len(length) function for counting
print("Positive Sentiment:", '%.2f' % len(positive_list), end='\n')
print("Neutral Sentiment:", '%.2f' % len(neutral_list), end='\n')
print("Negative Sentiment:", '%.2f' % len(negative_list), end='\n')

#Creating PieCart
labels = ['Positive ['+str(round(positive))+'%]' , 'Neutral ['+str(round(neutral))+'%]','Negative ['+str(round(negative))+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for stock= "+company_name+"" )
plt.axis('equal')
plt.show()

# Word cloud visualization
def word_cloud(text):
    stopwords = set(STOPWORDS)
    allWords = ' '.join([nws for nws in text])
    wordCloud = WordCloud(background_color='black',width = 1600, height = 800,stopwords = stopwords,min_font_size = 20,max_font_size=150,colormap='prism').generate(allWords)
    fig, ax = plt.subplots(figsize=(20,10), facecolor='k')
    plt.imshow(wordCloud)
    ax.axis("off")
    fig.tight_layout(pad=0)
    plt.show()

print('Wordcloud for ' + company_name)
word_cloud(news_df['Summary'].values)

# %%
# %store testOct
# Out:
# Stored 'testOct' (DataFrame)

# %%
# %store -r test

# %%
testNov
# Out:
#          Date                                            Summary  \
# 0  2021-12-20  Conglomerates such as Tata group, Reliance Ind...
# 1  2021-12-27  Reliance Industries chairman Mukesh Ambani has...
# 2  2022-01-03  MUMBAI: The government is likely to value Life...
# 3  2022-01-05  The matter was being heard by Chief Justice DN...
# 4  2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 5  2022-01-07  Reliance Industries, the Indian conglomerate c...
# 6  2022-01-09  Reliance Industries, the Indian conglomerate c...
# 7  2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...
#
#                                              Article
# 0  Conglomerates such as Tata group, Reliance Ind...
# 1  Reliance Industries chairman Mukesh Ambani has...
# 2  MUMBAI: The government is likely to value Life...
# 3  The matter was being heard by Chief Justice DN...
# 4  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 5  Reliance Industries, the Indian conglomerate c...
# ...

# %%
df = [testJan,testFeb,testMar,testApr,testMay,testJune,testJuly,testAug,testSep_1,testOct,testNov]
df
# Out:
# [         Date                                            Summary  \
#  0  2021-01-01  A look at the shareholders of Reliance Industr...
#  1  2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
#  2  2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
#  3  2021-01-04  Reliance Industries Limited, Tata Consultancy ...
#  4  2021-01-05  Equities may continue to see some further prof...
#  5  2021-01-06  India’s Tata Consultancy Services, popularly k...
#  6  2021-01-07  RISE Worldwide will continue to drive the full...
#  7  2021-01-08  Reliance Jio has emerged as the fifth stronges...
#  8  2021-01-09  Harish Salve, senior counsel appearing on beha...
#  9  2021-01-10  As per the report, the SFPC would act as an in...
#  10 2021-01-20  SEBI’s comments on the scheme include;Shares o...
#  11 2021-01-30  Amazon.com Inc's bid to stall Future Group's $...
#  12 2021-04-07  The market regulator's order says Reliance ope...
#
# ...

# %%
FinalDF=pd.concat(df)

FinalDF['Date']=pd.to_datetime(FinalDF['Date'])
FinalDF.reset_index(inplace=True)

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole)

#Assigning Initial Values
positive = 0
negative = 0
neutral = 0
#Creating empty lists
#news_list = []
polmap={}

#Iterating over the tweets in the dataframe
for news in FinalDF['Summary']:
    #news_list.append(news)
    analyzer = SentimentIntensityAnalyzer().polarity_scores(news)
    neg = analyzer['neg']
    neu = analyzer['neu']
    pos = analyzer['pos']
    comp = analyzer['compound']
    print(neg,pos,neu,comp)
    polmap.setdefault('Negative',[]).append(neg)
    polmap.setdefault('Positive',[]).append(pos)
    polmap.setdefault('Neutral',[]).append(neu)
    polmap.setdefault('Comp',[]).append(comp)
# Out:
# 0.036 0.123 0.842 0.9999
# 0.018 0.098 0.884 0.9999
# 0.027 0.124 0.85 0.9995
# 0.093 0.099 0.808 0.9278
# 0.043 0.111 0.847 0.9999
# 0.077 0.118 0.806 0.9979
# 0.027 0.141 0.832 0.9998
# 0.032 0.094 0.873 0.9988
# 0.03 0.136 0.833 0.9995
# 0.044 0.041 0.915 -0.4404
# 0.021 0.135 0.844 0.9981
# 0.072 0.095 0.833 0.7717
# 0.084 0.097 0.819 0.1779
# 0.02 0.044 0.936 0.743
# 0.047 0.126 0.827 0.9993
# 0.016 0.058 0.926 0.9892
# 0.029 0.102 0.869 0.9999
# 0.045 0.108 0.846 0.9981
# 0.046 0.119 0.835 0.9868
# 0.042 0.039 0.918 -0.8462
# 0.016 0.127 0.857 0.9989
# 0.034 0.086 0.88 0.9979
# 0.041 0.161 0.798 0.9217
# 0.046 0.083 0.871 0.9531
# 0.058 0.062 0.88 0.6048
# 0.059 0.074 0.867 0.1326
# 0.029 0.086 0.886 0.9908
# 0.08 0.123 0.797 0.9975
# 0.052 0.089 0.859 0.997
# 0.039 0.096 0.865 0.9611
# 0.059 0.046 0.895 -0.9863
# 0.048 0.098 0.853 0.998
# 0.043 0.112 0.846 0.9996
# 0.029 0.117 0.854 0.9992
# 0.03 0.072 0.898 0.9657
# 0.0 0.057 0.943 0.91
# 0.027 0.059 0.914 0.9885
# ...

# %%
NewDF=pd.DataFrame(polmap)
NewDF
# Out:
#      Negative  Positive  Neutral    Comp
# 0       0.036     0.123    0.842  0.9999
# 1       0.018     0.098    0.884  0.9999
# 2       0.027     0.124    0.850  0.9995
# 3       0.093     0.099    0.808  0.9278
# 4       0.043     0.111    0.847  0.9999
# ..        ...       ...      ...     ...
# 104     0.010     0.139    0.852  0.9806
# 105     0.032     0.093    0.875  0.9993
# 106     0.014     0.109    0.877  0.9987
# 107     0.009     0.066    0.925  0.9969
# 108     0.015     0.070    0.914  0.9941
#
# [109 rows x 4 columns]

# %%
PolDF=pd.concat([FinalDF,NewDF],axis=1)
PolDF
# Out:
#      index       Date                                            Summary  \
# 0        0 2021-01-01  A look at the shareholders of Reliance Industr...
# 1        1 2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
# 2        2 2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
# 3        3 2021-01-04  Reliance Industries Limited, Tata Consultancy ...
# 4        4 2021-01-05  Equities may continue to see some further prof...
# ..     ...        ...                                                ...
# 104      3 2022-01-05  The matter was being heard by Chief Justice DN...
# 105      4 2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 106      5 2022-01-07  Reliance Industries, the Indian conglomerate c...
# 107      6 2022-01-09  Reliance Industries, the Indian conglomerate c...
# 108      7 2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...
#
#                                                Article  Negative  Positive  \
# ...

# %%
# %store PolDF
# Out:
# Stored 'PolDF' (DataFrame)

# %%
# %store -r df_new

# %%
df_new.columns=['Date','Summary']
df_new
# Out:
#            Date                                            Summary
# 0    2021-01-10  2 days spend but can't find a single stock tha...
# 1    2021-01-11  Few companies drive stock market across the wo...
# 2    2021-01-12  Reliance Industries (RIL) is a good stock?,The...
# 3    2021-01-13  HDFC Bank has replaced Reliance Industries to ...
# 4    2021-01-14  reliance Bhartiartl  drreddy cipla biocon \n m...
# ..          ...                                                ...
# 337  2022-01-05  Best performing large cap stocks from today\n\...
# 338  2022-01-06  Mutual Fund Top Holding Stocks \n\n- Infosys\n...
# 339  2022-01-07  Trading Styles\n\nBreakout - price breaks abv ...
# 340  2022-01-08  Stock to watch ..for coming week …IRCTC ..reli...
# 341  2022-01-09  Next week Nifty Bknifty Consolidation and time...
#
# [342 rows x 2 columns]

# %%
ArtDF=FinalDF.iloc[:,:3]
ArtDF.dr
# Out:
#      index       Date                                            Summary
# 0        0 2021-01-01  A look at the shareholders of Reliance Industr...
# 1        1 2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
# 2        2 2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
# 3        3 2021-01-04  Reliance Industries Limited, Tata Consultancy ...
# 4        4 2021-01-05  Equities may continue to see some further prof...
# ..     ...        ...                                                ...
# 104      3 2022-01-05  The matter was being heard by Chief Justice DN...
# 105      4 2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 106      5 2022-01-07  Reliance Industries, the Indian conglomerate c...
# 107      6 2022-01-09  Reliance Industries, the Indian conglomerate c...
# 108      7 2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...
#
# [109 rows x 3 columns]

# %%
ArtDF.drop('index', axis=1, inplace=True)
ArtDF
# Out:
#           Date                                            Summary
# 0   2021-01-01  A look at the shareholders of Reliance Industr...
# 1   2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
# 2   2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
# 3   2021-01-04  Reliance Industries Limited, Tata Consultancy ...
# 4   2021-01-05  Equities may continue to see some further prof...
# ..         ...                                                ...
# 104 2022-01-05  The matter was being heard by Chief Justice DN...
# 105 2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 106 2022-01-07  Reliance Industries, the Indian conglomerate c...
# 107 2022-01-09  Reliance Industries, the Indian conglomerate c...
# 108 2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...
#
# [109 rows x 2 columns]

# %%
NewCombineDF=pd.concat([ArtDF,df_new])
NewCombineDF['Date']=pd.to_datetime(NewCombineDF['Date'])
NewCombineDF
# Out:
#           Date                                            Summary
# 0   2021-01-01  A look at the shareholders of Reliance Industr...
# 1   2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
# 2   2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
# 3   2021-01-04  Reliance Industries Limited, Tata Consultancy ...
# 4   2021-01-05  Equities may continue to see some further prof...
# ..         ...                                                ...
# 337 2022-01-05  Best performing large cap stocks from today\n\...
# 338 2022-01-06  Mutual Fund Top Holding Stocks \n\n- Infosys\n...
# 339 2022-01-07  Trading Styles\n\nBreakout - price breaks abv ...
# 340 2022-01-08  Stock to watch ..for coming week …IRCTC ..reli...
# 341 2022-01-09  Next week Nifty Bknifty Consolidation and time...
#
# [451 rows x 2 columns]

# %%
NewCombineDF=NewCombineDF.groupby(['Date'], as_index = False).agg({'Summary': ','.join})
NewCombineDF
# Out:
#           Date                                            Summary
# 0   2021-01-01  A look at the shareholders of Reliance Industr...
# 1   2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...
# 2   2021-01-03  During the Q3 FY21 earnings call, the JPL mana...
# 3   2021-01-04  Reliance Industries Limited, Tata Consultancy ...
# 4   2021-01-05  Equities may continue to see some further prof...
# ..         ...                                                ...
# 354 2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...
# 355 2022-01-07  Reliance Industries, the Indian conglomerate c...
# 356 2022-01-08  Stock to watch ..for coming week …IRCTC ..reli...
# 357 2022-01-09  Reliance Industries, the Indian conglomerate c...
# 358 2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...
#
# [359 rows x 2 columns]

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole)

#Assigning Initial Values
positive = 0
negative = 0
neutral = 0
#Creating empty lists
#news_list = []
polmap={}

#Iterating over the tweets in the dataframe
for news in NewCombineDF['Summary']:
    #news_list.append(news)
    analyzer = SentimentIntensityAnalyzer().polarity_scores(news)
    neg = analyzer['neg']
    neu = analyzer['neu']
    pos = analyzer['pos']
    comp = analyzer['compound']
    print(neg,pos,neu,comp)
    polmap.setdefault('Negative',[]).append(neg)
    polmap.setdefault('Positive',[]).append(pos)
    polmap.setdefault('Neutral',[]).append(neu)
    polmap.setdefault('Comp',[]).append(comp)
# Out:
# 0.036 0.123 0.842 0.9999
# 0.018 0.098 0.884 0.9999
# 0.027 0.124 0.85 0.9995
# 0.093 0.099 0.808 0.9278
# 0.043 0.111 0.847 0.9999
# 0.077 0.118 0.806 0.9979
# 0.027 0.141 0.832 0.9998
# 0.032 0.094 0.873 0.9988
# 0.03 0.136 0.833 0.9995
# 0.047 0.044 0.909 -0.5035
# 0.021 0.177 0.802 0.9739
# 0.056 0.101 0.843 0.882
# 0.045 0.029 0.927 -0.128
# 0.054 0.038 0.908 -0.1873
# 0.033 0.155 0.813 0.8957
# 0.184 0.03 0.786 -0.886
# 0.026 0.052 0.922 0.1901
# 0.011 0.118 0.871 0.9591
# 0.0 0.148 0.852 0.9615
# 0.035 0.143 0.822 0.9987
# 0.022 0.144 0.833 0.9969
# 0.03 0.167 0.803 0.9923
# 0.079 0.14 0.781 0.9169
# 0.083 0.075 0.841 -0.3691
# 0.021 0.145 0.834 0.9977
# 0.0 0.1 0.9 0.8919
# 0.043 0.124 0.833 0.9857
# 0.021 0.139 0.84 0.9701
# 0.077 0.055 0.867 -0.4003
# 0.068 0.102 0.829 0.9516
# 0.074 0.17 0.755 0.9345
# 0.021 0.057 0.921 0.9403
# 0.047 0.133 0.82 0.9995
# 0.03 0.103 0.867 0.9999
# 0.044 0.114 0.842 0.9989
# 0.039 0.093 0.868 0.9772
# 0.042 0.039 0.918 -0.8462
# ...

# %%
NewDF=pd.DataFrame(polmap)
NewDF
# Out:
#      Negative  Positive  Neutral    Comp
# 0       0.036     0.123    0.842  0.9999
# 1       0.018     0.098    0.884  0.9999
# 2       0.027     0.124    0.850  0.9995
# 3       0.093     0.099    0.808  0.9278
# 4       0.043     0.111    0.847  0.9999
# ..        ...       ...      ...     ...
# 354     0.032     0.092    0.875  0.9994
# 355     0.016     0.107    0.877  0.9989
# 356     0.000     0.000    1.000  0.0000
# 357     0.008     0.074    0.918  0.9980
# 358     0.015     0.070    0.914  0.9941
#
# [359 rows x 4 columns]

# %%
PolDF=pd.concat([NewCombineDF,NewDF],axis=1)
PolDF
# Out:
#           Date                                            Summary  Negative  \
# 0   2021-01-01  A look at the shareholders of Reliance Industr...     0.036
# 1   2021-01-02  JSPL: Jindal Steel and Power Ltd reported a ne...     0.018
# 2   2021-01-03  During the Q3 FY21 earnings call, the JPL mana...     0.027
# 3   2021-01-04  Reliance Industries Limited, Tata Consultancy ...     0.093
# 4   2021-01-05  Equities may continue to see some further prof...     0.043
# ..         ...                                                ...       ...
# 354 2022-01-06  Shapoorji Pallonji on Thursday sold 1,84,00,00...     0.032
# 355 2022-01-07  Reliance Industries, the Indian conglomerate c...     0.016
# 356 2022-01-08  Stock to watch ..for coming week …IRCTC ..reli...     0.000
# 357 2022-01-09  Reliance Industries, the Indian conglomerate c...     0.008
# 358 2022-01-10  On Jan. 8, Reliance Industries (RIL) announced...     0.015
#
#      Positive  Neutral    Comp
# ...

# %%
# %store PolDF
# Out:
# Stored 'PolDF' (DataFrame)

# %%
PolDF.to_excel('pol.xlsx')
